# %% [markdown]
# <a href="https://colab.research.google.com/github/bardiaHSZD/Algorithms_DataStructure/blob/main/Problem_Solving_Approaches.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Problem Solving Approaches**

# %% [markdown]
# ## **Introduction**

# %% [markdown]
# ### **Recipe For Problem Solving**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **1. Understand the Problem**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **2. Explore Examples**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **3. Break it Down**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## **4. Solve or Simplify**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Things to remember:
# *   Ask suggestions from the interviewer.
# *   Use the internet connection to find syntax.
# *   Going this far, even upto 90%, shows your ability in problem solving.
#
# Things to fix, the remaining 10%, is to remove space counting, etc.

# %% [markdown]
# ## **5. Look Back and Refactor**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Final Marks:
#
# *   You should write down the plan before coding.
# *   Refactor your code: improve readability and performance, add the difficulties you ignored, look into other people's solution(s).

# %% [markdown]
# ![image.png](data:image/png;base64,...)
